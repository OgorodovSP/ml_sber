# %%
import pandas as pd
import featuretools as ft
from woodwork.logical_types import Categorical, Double, Datetime, Age


from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.3f}'.format)

import warnings
warnings.filterwarnings('ignore')

# %%
df_for_feature = pd.read_csv('../data/df_for_modeling.csv')
df_for_feature.sample(5)
# Out:
#                      client_id  visit_number            utm_source  \
# 1659998         1866961831.164         1.000  ZpYIoDJMcFzVoPFsHGJL
# 1430496         1634465986.162         1.000  fDLlAcSmythWSCVMvqvL
# 1151532         1349442635.164         2.000  kjsLglQLzykiRbcDiGcD
# 1429174         1633045836.163         1.000  MvfHsxITijuriZxsqZqt
# 1629449  1835721281.1637667081         1.000  ZpYIoDJMcFzVoPFsHGJL
#
#           utm_medium          utm_campaign         utm_adcontent  \
# 1659998       banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 1430496       (none)  LTuZkdKfxRGVceoWkVyg  JNHcPlZPxEMWDnRiyoBf
# 1151532          cpc  labpJCBQmsoWLfQvNTak  JNHcPlZPxEMWDnRiyoBf
# 1429174          cpm  FTjNLDyTrXaWYgZymFkV  PkybGvWbaqORmxjNunqZ
# 1629449  smartbanner  jqlUOdZBNZYfInQVcZlS  SAVVWaMghGnnvPOqMOIt
#
#                   utm_keyword device_category device_os device_brand  \
# 1659998  puhZPIYqKXeFPaUviSjo          mobile   Android      Samsung
# 1430496  puhZPIYqKXeFPaUviSjo          mobile       iOS        Apple
# 1151532  pdKhPCfdmCgicNfmtfqh          mobile       iOS        Apple
# 1429174  puhZPIYqKXeFPaUviSjo          tablet   Android       Huawei
# 1629449  puhZPIYqKXeFPaUviSjo          mobile   Android       Xiaomi
#
#         device_browser geo_country          geo_city  event_action  \
# 1659998         Chrome      Russia            Moscow             0
# 1430496         Safari      Russia            Moscow             0
# 1151532         Safari      Russia            Moscow             0
# 1429174         Chrome      Russia  Saint Petersburg             0
# 1629449         Chrome      Russia  Saint Petersburg             0
#
#          visit_month  visit_day  visit_hour  visit_minute  \
# 1659998           12         30          15            13
# 1430496            5         24          11             0
# 1151532           12         11          14            38
# 1429174            8         20           0             0
# 1629449           11         23          14            31
#
#          device_screen_width  device_screen_heiht
# 1659998                  360                  780
# 1430496                  414                  896
# 1151532                  428                  926
# 1429174                  958                  599
# 1629449                  393                  873
